# %%
import cv2
import numpy as np
import pandas as pd
import os
from skimage.feature import hog, local_binary_pattern
from sklearn.decomposition import PCA
from concurrent.futures import ProcessPoolExecutor
from sklearn.ensemble import RandomForestClassifier, VotingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.linear_model import Perceptron
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import accuracy_score, confusion_matrix
from concurrent.futures import ThreadPoolExecutor
import pickle
import matplotlib.pyplot as plt
import seaborn as sns

# %%
labels_df = pd.read_csv('label.csv')

image_directory = 'data'

# %%
# Function to extract ORB features
def extract_orb_features(image, max_features=128):
    orb = cv2.ORB_create()
    keypoints, descriptors = orb.detectAndCompute(image, None)
    if descriptors is not None:
        if descriptors.shape[0] > max_features:
            descriptors = descriptors[:max_features, :]
        elif descriptors.shape[0] < max_features:
            padding = np.zeros((max_features - descriptors.shape[0], descriptors.shape[1]))
            descriptors = np.vstack((descriptors, padding))
        return descriptors.flatten()
    else:
        return np.zeros(max_features * 32)

# Function to extract HOG features
def extract_hog_features(image):
    gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    features = hog(gray_image, pixels_per_cell=(24, 24), block_norm='L2-Hys')
    return features

# Function to extract LBP features
def extract_lbp_features(image, radii=[1, 2, 3], n_points=8, method='uniform'):
    gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    lbp_features = []
    
    for radius in radii:
        lbp = local_binary_pattern(gray_image, n_points, radius, method=method)
        hist, _ = np.histogram(lbp.ravel(), bins=np.arange(0, n_points + 3), range=(0, n_points + 2))
        hist = hist.astype("float")
        hist /= (hist.sum() + 1e-7)
        lbp_features.extend(hist)
    
    return np.array(lbp_features) 

# Function to extract color histogram features
def extract_color_histogram(image):
    # Load the image
    
    # Compute the histogram for each color channel (B, G, R)
    hist_b = cv2.calcHist([image], [0], None, [256], [0, 256])
    hist_g = cv2.calcHist([image], [1], None, [256], [0, 256])
    hist_r = cv2.calcHist([image], [2], None, [256], [0, 256])
    
    # Normalize the histograms
    hist_b = cv2.normalize(hist_b, hist_b).flatten()
    hist_g = cv2.normalize(hist_g, hist_g).flatten()
    hist_r = cv2.normalize(hist_r, hist_r).flatten()

    # Concatenate the histograms into a single feature vector
    hist_features = np.concatenate([hist_b, hist_g, hist_r])

    # print(hist_features.shape)

    return hist_features

# Function to extract SIFT features
def extract_sift_features(image, max_features=10):
    sift = cv2.SIFT_create()
    keypoints, descriptors = sift.detectAndCompute(image, None)
    if descriptors is not None:
        if descriptors.shape[0] > max_features:
            descriptors = descriptors[:max_features, :]
        elif descriptors.shape[0] < max_features:
            padding = np.zeros((max_features - descriptors.shape[0], descriptors.shape[1]))
            descriptors = np.vstack((descriptors, padding))
        # print("yeyyy")
        return descriptors.flatten()
    else:
        return np.zeros(max_features * 128)

# Combine all features into a single feature vector
def extract_combined_features(image):
    # Extract various features
    orb_features = extract_orb_features(image)
    hog_features = extract_hog_features(image)
    lbp_features = extract_lbp_features(image)
    color_histogram = extract_color_histogram(image)
    sift_features = extract_sift_features(image)

    # Combine all features into a single array
    combined_features = np.concatenate((
        orb_features, 
        hog_features, 
        lbp_features, 
        color_histogram, 
        sift_features, 
        # gftt_features, 
        # sobel_features
    ))
    return combined_features

# %%
X = labels_df['filename']
y = labels_df['label']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8, random_state=42)

# %%
def process_image(image_name, label):
    # print(image_name, label)
    image_path = os.path.join(image_directory, image_name)
    try:
        image = cv2.imread(image_path)
    except:
        return None

    if image is None:
        return None

    # Resize image
    resized_image = cv2.resize(image, (250, 200))

    # Extract combined features
    combined_features = extract_combined_features(resized_image)
    # print(len(combined_features))

    # Return the features with the label
    return np.append(combined_features, label)

# %%
def extract_features(image_names, labels):
    results = []

    def process_and_store(image_name, label):
        result = process_image(image_name, label)
        if result is not None:
            results.append(result)

    with ThreadPoolExecutor() as executor:
        # Submit tasks to the executor
        executor.map(process_and_store, image_names, labels)

    return np.array(results)

# %%
print(X_train.head())
# Out:
# 12359    Image_12360.jpg
# 9243      Image_9244.jpg
# 11838    Image_11839.jpg
# 3524      Image_3525.jpg
# 3475      Image_3476.jpg
# Name: filename, dtype: object

# %%
print(y_train.head())
# Out:
# 12359     cycling
# 9243     drinking
# 11838    clapping
# 3524      texting
# 3475      cycling
# Name: label, dtype: object

# %%
print("Shape of train_features:", X_train.shape)
print("Shape of test_features:", X_test.shape)
# Out:
# Shape of train_features: (10080,)
# Shape of test_features: (2520,)

# %%
train_features = extract_features(X_train, y_train)
test_features = extract_features(X_test, y_test)

# Separate features and labels
X_train_features = train_features[:, :-1]
y_train_labels = train_features[:, -1]

X_test_features = test_features[:, :-1]
y_test_labels = test_features[:, -1]
# Out:
# [ WARN:0@0.896] global loadsave.cpp:241 findDecoder imread_('data/Image_9244.jpg'): can't open/read file: check file path/integrity
# [ WARN:9@0.901] global loadsave.cpp:241 findDecoder imread_('data/Image_7832.jpg'): can't open/read file: check file path/integrity
# [ WARN:11@0.902] global loadsave.cpp:241 findDecoder imread_('data/Image_8036.jpg'): can't open/read file: check file path/integrity
# [ WARN:12@0.902] global loadsave.cpp:241 findDecoder imread_('data/Image_977.jpg'): can't open/read file: check file path/integrity
# [ WARN:12@0.903] global loadsave.cpp:241 findDecoder imread_('data/Image_9751.jpg'): can't open/read file: check file path/integrity
# [ WARN:16@0.904] global loadsave.cpp:241 findDecoder imread_('data/Image_8218.jpg'): can't open/read file: check file path/integrity
# [ WARN:19@0.904] global loadsave.cpp:241 findDecoder imread_('data/Image_9319.jpg'): can't open/read file: check file path/integrity
# [ WARN:19@0.905] global loadsave.cpp:241 findDecoder imread_('data/Image_8920.jpg'): can't open/read file: check file path/integrity
# [ WARN:19@0.905] global loadsave.cpp:241 findDecoder imread_('data/Image_9641.jpg'): can't open/read file: check file path/integrity
# [ WARN:23@0.907] global loadsave.cpp:241 findDecoder imread_('data/Image_9831.jpg'): can't open/read file: check file path/integrity
# [ WARN:31@1.223] global loadsave.cpp:241 findDecoder imread_('data/Image_9535.jpg'): can't open/read file: check file path/integrity
# [ WARN:31@1.223] global loadsave.cpp:241 findDecoder imread_('data/Image_8457.jpg'): can't open/read file: check file path/integrity
# [ WARN:1@1.246] global loadsave.cpp:241 findDecoder imread_('data/Image_9799.jpg'): can't open/read file: check file path/integrity
# [ WARN:2@1.271] global loadsave.cpp:241 findDecoder imread_('data/Image_9620.jpg'): can't open/read file: check file path/integrity
# [ WARN:11@1.305] global loadsave.cpp:241 findDecoder imread_('data/Image_9787.jpg'): can't open/read file: check file path/integrity
# [ WARN:22@1.319] global loadsave.cpp:241 findDecoder imread_('data/Image_9378.jpg'): can't open/read file: check file path/integrity
# [ WARN:15@1.381] global loadsave.cpp:241 findDecoder imread_('data/Image_882.jpg'): can't open/read file: check file path/integrity
# [ WARN:23@1.427] global loadsave.cpp:241 findDecoder imread_('data/Image_9810.jpg'): can't open/read file: check file path/integrity
# [ WARN:1@1.476] global loadsave.cpp:241 findDecoder imread_('data/Image_8892.jpg'): can't open/read file: check file path/integrity
# [ WARN:4@1.517] global loadsave.cpp:241 findDecoder imread_('data/Image_8261.jpg'): can't open/read file: check file path/integrity
# [ WARN:16@1.609] global loadsave.cpp:241 findDecoder imread_('data/Image_9826.jpg'): can't open/read file: check file path/integrity
# [ WARN:16@1.618] global loadsave.cpp:241 findDecoder imread_('data/Image_8380.jpg'): can't open/read file: check file path/integrity
# [ WARN:16@1.626] global loadsave.cpp:241 findDecoder imread_('data/Image_7758.jpg'): can't open/read file: check file path/integrity
# [ WARN:13@1.633] global loadsave.cpp:241 findDecoder imread_('data/Image_8954.jpg'): can't open/read file: check file path/integrity
# [ WARN:20@1.654] global loadsave.cpp:241 findDecoder imread_('data/Image_8272.jpg'): can't open/read file: check file path/integrity
# [ WARN:5@1.659] global loadsave.cpp:241 findDecoder imread_('data/Image_8696.jpg'): can't open/read file: check file path/integrity
# [ WARN:21@1.664] global loadsave.cpp:241 findDecoder imread_('data/Image_8604.jpg'): can't open/read file: check file path/integrity
# [ WARN:5@1.666] global loadsave.cpp:241 findDecoder imread_('data/Image_9037.jpg'): can't open/read file: check file path/integrity
# [ WARN:4@1.739] global loadsave.cpp:241 findDecoder imread_('data/Image_8385.jpg'): can't open/read file: check file path/integrity
# [ WARN:3@1.845] global loadsave.cpp:241 findDecoder imread_('data/Image_8827.jpg'): can't open/read file: check file path/integrity
# [ WARN:3@1.853] global loadsave.cpp:241 findDecoder imread_('data/Image_9122.jpg'): can't open/read file: check file path/integrity
# [ WARN:11@1.870] global loadsave.cpp:241 findDecoder imread_('data/Image_8553.jpg'): can't open/read file: check file path/integrity
# [ WARN:11@1.871] global loadsave.cpp:241 findDecoder imread_('data/Image_9291.jpg'): can't open/read file: check file path/integrity
# [ WARN:27@1.910] global loadsave.cpp:241 findDecoder imread_('data/Image_9676.jpg'): can't open/read file: check file path/integrity
# [ WARN:29@1.953] global loadsave.cpp:241 findDecoder imread_('data/Image_9022.jpg'): can't open/read file: check file path/integrity
# [ WARN:17@1.985] global loadsave.cpp:241 findDecoder imread_('data/Image_8486.jpg'): can't open/read file: check file path/integrity
# [ WARN:10@2.003] global loadsave.cpp:241 findDecoder imread_('data/Image_9255.jpg'): can't open/read file: check file path/integrity
# [ WARN:19@2.098] global loadsave.cpp:241 findDecoder imread_('data/Image_8749.jpg'): can't open/read file: check file path/integrity
# [ WARN:31@2.213] global loadsave.cpp:241 findDecoder imread_('data/Image_7753.jpg'): can't open/read file: check file path/integrity
# [ WARN:10@2.259] global loadsave.cpp:241 findDecoder imread_('data/Image_9724.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@2.272] global loadsave.cpp:241 findDecoder imread_('data/Image_8621.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@2.272] global loadsave.cpp:241 findDecoder imread_('data/Image_9322.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@2.272] global loadsave.cpp:241 findDecoder imread_('data/Image_8594.jpg'): can't open/read file: check file path/integrity
# [ WARN:4@2.297] global loadsave.cpp:241 findDecoder imread_('data/Image_8125.jpg'): can't open/read file: check file path/integrity
# [ WARN:4@2.299] global loadsave.cpp:241 findDecoder imread_('data/Image_8607.jpg'): can't open/read file: check file path/integrity
# [ WARN:13@2.314] global loadsave.cpp:241 findDecoder imread_('data/Image_9899.jpg'): can't open/read file: check file path/integrity
# [ WARN:5@2.391] global loadsave.cpp:241 findDecoder imread_('data/Image_7913.jpg'): can't open/read file: check file path/integrity
# [ WARN:5@2.393] global loadsave.cpp:241 findDecoder imread_('data/Image_8441.jpg'): can't open/read file: check file path/integrity
# [ WARN:8@2.438] global loadsave.cpp:241 findDecoder imread_('data/Image_9103.jpg'): can't open/read file: check file path/integrity
# [ WARN:7@2.464] global loadsave.cpp:241 findDecoder imread_('data/Image_9888.jpg'): can't open/read file: check file path/integrity
# [ WARN:29@2.485] global loadsave.cpp:241 findDecoder imread_('data/Image_7768.jpg'): can't open/read file: check file path/integrity
# [ WARN:5@2.580] global loadsave.cpp:241 findDecoder imread_('data/Image_9951.jpg'): can't open/read file: check file path/integrity
# [ WARN:19@2.628] global loadsave.cpp:241 findDecoder imread_('data/Image_8935.jpg'): can't open/read file: check file path/integrity
# [ WARN:16@2.651] global loadsave.cpp:241 findDecoder imread_('data/Image_8152.jpg'): can't open/read file: check file path/integrity
# [ WARN:7@2.755] global loadsave.cpp:241 findDecoder imread_('data/Image_8105.jpg'): can't open/read file: check file path/integrity
# [ WARN:25@2.802] global loadsave.cpp:241 findDecoder imread_('data/Image_9304.jpg'): can't open/read file: check file path/integrity
# [ WARN:25@2.809] global loadsave.cpp:241 findDecoder imread_('data/Image_9464.jpg'): can't open/read file: check file path/integrity
# [ WARN:15@2.810] global loadsave.cpp:241 findDecoder imread_('data/Image_9710.jpg'): can't open/read file: check file path/integrity
# [ WARN:24@2.946] global loadsave.cpp:241 findDecoder imread_('data/Image_974.jpg'): can't open/read file: check file path/integrity
# [ WARN:11@3.002] global loadsave.cpp:241 findDecoder imread_('data/Image_7774.jpg'): can't open/read file: check file path/integrity
# [ WARN:22@3.026] global loadsave.cpp:241 findDecoder imread_('data/Image_9891.jpg'): can't open/read file: check file path/integrity
# [ WARN:12@3.031] global loadsave.cpp:241 findDecoder imread_('data/Image_8853.jpg'): can't open/read file: check file path/integrity
# [ WARN:20@3.137] global loadsave.cpp:241 findDecoder imread_('data/Image_8679.jpg'): can't open/read file: check file path/integrity
# [ WARN:27@3.190] global loadsave.cpp:241 findDecoder imread_('data/Image_9630.jpg'): can't open/read file: check file path/integrity
# [ WARN:24@3.234] global loadsave.cpp:241 findDecoder imread_('data/Image_910.jpg'): can't open/read file: check file path/integrity
# [ WARN:16@3.260] global loadsave.cpp:241 findDecoder imread_('data/Image_9610.jpg'): can't open/read file: check file path/integrity
# [ WARN:15@3.270] global loadsave.cpp:241 findDecoder imread_('data/Image_8651.jpg'): can't open/read file: check file path/integrity
# [ WARN:9@3.375] global loadsave.cpp:241 findDecoder imread_('data/Image_7943.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@3.422] global loadsave.cpp:241 findDecoder imread_('data/Image_8481.jpg'): can't open/read file: check file path/integrity
# [ WARN:3@3.439] global loadsave.cpp:241 findDecoder imread_('data/Image_837.jpg'): can't open/read file: check file path/integrity
# [ WARN:3@3.441] global loadsave.cpp:241 findDecoder imread_('data/Image_9270.jpg'): can't open/read file: check file path/integrity
# [ WARN:11@3.559] global loadsave.cpp:241 findDecoder imread_('data/Image_9070.jpg'): can't open/read file: check file path/integrity
# [ WARN:11@3.566] global loadsave.cpp:241 findDecoder imread_('data/Image_7863.jpg'): can't open/read file: check file path/integrity
# [ WARN:12@3.601] global loadsave.cpp:241 findDecoder imread_('data/Image_9785.jpg'): can't open/read file: check file path/integrity
# [ WARN:6@3.658] global loadsave.cpp:241 findDecoder imread_('data/Image_9922.jpg'): can't open/read file: check file path/integrity
# [ WARN:23@3.708] global loadsave.cpp:241 findDecoder imread_('data/Image_8850.jpg'): can't open/read file: check file path/integrity
# [ WARN:5@3.719] global loadsave.cpp:241 findDecoder imread_('data/Image_8317.jpg'): can't open/read file: check file path/integrity
# [ WARN:19@3.773] global loadsave.cpp:241 findDecoder imread_('data/Image_9587.jpg'): can't open/read file: check file path/integrity
# [ WARN:30@3.787] global loadsave.cpp:241 findDecoder imread_('data/Image_8305.jpg'): can't open/read file: check file path/integrity
# [ WARN:11@3.873] global loadsave.cpp:241 findDecoder imread_('data/Image_9206.jpg'): can't open/read file: check file path/integrity
# [ WARN:28@3.928] global loadsave.cpp:241 findDecoder imread_('data/Image_795.jpg'): can't open/read file: check file path/integrity
# [ WARN:7@3.975] global loadsave.cpp:241 findDecoder imread_('data/Image_8160.jpg'): can't open/read file: check file path/integrity
# [ WARN:23@3.986] global loadsave.cpp:241 findDecoder imread_('data/Image_9675.jpg'): can't open/read file: check file path/integrity
# [ WARN:29@4.058] global loadsave.cpp:241 findDecoder imread_('data/Image_7862.jpg'): can't open/read file: check file path/integrity
# [ WARN:24@4.122] global loadsave.cpp:241 findDecoder imread_('data/Image_9198.jpg'): can't open/read file: check file path/integrity
# [ WARN:3@4.214] global loadsave.cpp:241 findDecoder imread_('data/Image_9013.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4.224] global loadsave.cpp:241 findDecoder imread_('data/Image_940.jpg'): can't open/read file: check file path/integrity
# [ WARN:30@4.253] global loadsave.cpp:241 findDecoder imread_('data/Image_9298.jpg'): can't open/read file: check file path/integrity
# [ WARN:23@4.358] global loadsave.cpp:241 findDecoder imread_('data/Image_958.jpg'): can't open/read file: check file path/integrity
# [ WARN:11@4.384] global loadsave.cpp:241 findDecoder imread_('data/Image_8525.jpg'): can't open/read file: check file path/integrity
# [ WARN:31@4.411] global loadsave.cpp:241 findDecoder imread_('data/Image_8164.jpg'): can't open/read file: check file path/integrity
# [ WARN:28@4.453] global loadsave.cpp:241 findDecoder imread_('data/Image_9453.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@4.480] global loadsave.cpp:241 findDecoder imread_('data/Image_8172.jpg'): can't open/read file: check file path/integrity
# [ WARN:27@4.495] global loadsave.cpp:241 findDecoder imread_('data/Image_8900.jpg'): can't open/read file: check file path/integrity
# [ WARN:18@4.561] global loadsave.cpp:241 findDecoder imread_('data/Image_9622.jpg'): can't open/read file: check file path/integrity
# [ WARN:26@4.569] global loadsave.cpp:241 findDecoder imread_('data/Image_8613.jpg'): can't open/read file: check file path/integrity
# [ WARN:26@4.575] global loadsave.cpp:241 findDecoder imread_('data/Image_8219.jpg'): can't open/read file: check file path/integrity
# [ WARN:18@4.575] global loadsave.cpp:241 findDecoder imread_('data/Image_8953.jpg'): can't open/read file: check file path/integrity
# [ WARN:20@4.592] global loadsave.cpp:241 findDecoder imread_('data/Image_9603.jpg'): can't open/read file: check file path/integrity
# [ WARN:26@4.592] global loadsave.cpp:241 findDecoder imread_('data/Image_9707.jpg'): can't open/read file: check file path/integrity
# [ WARN:5@4.610] global loadsave.cpp:241 findDecoder imread_('data/Image_9923.jpg'): can't open/read file: check file path/integrity
# [ WARN:17@4.632] global loadsave.cpp:241 findDecoder imread_('data/Image_9961.jpg'): can't open/read file: check file path/integrity
# [ WARN:17@4.632] global loadsave.cpp:241 findDecoder imread_('data/Image_8976.jpg'): can't open/read file: check file path/integrity
# [ WARN:10@4.647] global loadsave.cpp:241 findDecoder imread_('data/Image_8460.jpg'): can't open/read file: check file path/integrity
# [ WARN:15@4.661] global loadsave.cpp:241 findDecoder imread_('data/Image_9430.jpg'): can't open/read file: check file path/integrity
# [ WARN:2@4.709] global loadsave.cpp:241 findDecoder imread_('data/Image_94.jpg'): can't open/read file: check file path/integrity
# [ WARN:6@4.715] global loadsave.cpp:241 findDecoder imread_('data/Image_8577.jpg'): can't open/read file: check file path/integrity
# [ WARN:2@4.719] global loadsave.cpp:241 findDecoder imread_('data/Image_8992.jpg'): can't open/read file: check file path/integrity
# [ WARN:29@4.758] global loadsave.cpp:241 findDecoder imread_('data/Image_8705.jpg'): can't open/read file: check file path/integrity
# [ WARN:7@4.810] global loadsave.cpp:241 findDecoder imread_('data/Image_8752.jpg'): can't open/read file: check file path/integrity
# [ WARN:5@4.855] global loadsave.cpp:241 findDecoder imread_('data/Image_9096.jpg'): can't open/read file: check file path/integrity
# [ WARN:20@4.866] global loadsave.cpp:241 findDecoder imread_('data/Image_9108.jpg'): can't open/read file: check file path/integrity
# [ WARN:1@4.871] global loadsave.cpp:241 findDecoder imread_('data/Image_8405.jpg'): can't open/read file: check file path/integrity
# [ WARN:1@4.871] global loadsave.cpp:241 findDecoder imread_('data/Image_8910.jpg'): can't open/read file: check file path/integrity
# [ WARN:30@5.040] global loadsave.cpp:241 findDecoder imread_('data/Image_8914.jpg'): can't open/read file: check file path/integrity
# [ WARN:27@5.069] global loadsave.cpp:241 findDecoder imread_('data/Image_9283.jpg'): can't open/read file: check file path/integrity
# [ WARN:28@5.108] global loadsave.cpp:241 findDecoder imread_('data/Image_8202.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@5.198] global loadsave.cpp:241 findDecoder imread_('data/Image_8205.jpg'): can't open/read file: check file path/integrity
# [ WARN:29@5.304] global loadsave.cpp:241 findDecoder imread_('data/Image_8716.jpg'): can't open/read file: check file path/integrity
# [ WARN:4@5.385] global loadsave.cpp:241 findDecoder imread_('data/Image_8779.jpg'): can't open/read file: check file path/integrity
# [ WARN:4@5.390] global loadsave.cpp:241 findDecoder imread_('data/Image_9645.jpg'): can't open/read file: check file path/integrity
# [ WARN:19@5.405] global loadsave.cpp:241 findDecoder imread_('data/Image_7742.jpg'): can't open/read file: check file path/integrity
# [ WARN:11@5.429] global loadsave.cpp:241 findDecoder imread_('data/Image_9426.jpg'): can't open/read file: check file path/integrity
# [ WARN:18@5.495] global loadsave.cpp:241 findDecoder imread_('data/Image_8540.jpg'): can't open/read file: check file path/integrity
# [ WARN:22@5.536] global loadsave.cpp:241 findDecoder imread_('data/Image_9302.jpg'): can't open/read file: check file path/integrity
# [ WARN:2@5.541] global loadsave.cpp:241 findDecoder imread_('data/Image_789.jpg'): can't open/read file: check file path/integrity
# [ WARN:9@5.602] global loadsave.cpp:241 findDecoder imread_('data/Image_8971.jpg'): can't open/read file: check file path/integrity
# [ WARN:9@5.602] global loadsave.cpp:241 findDecoder imread_('data/Image_9569.jpg'): can't open/read file: check file path/integrity
# [ WARN:9@5.602] global loadsave.cpp:241 findDecoder imread_('data/Image_8903.jpg'): can't open/read file: check file path/integrity
# [ WARN:5@5.633] global loadsave.cpp:241 findDecoder imread_('data/Image_9532.jpg'): can't open/read file: check file path/integrity
# [ WARN:31@5.653] global loadsave.cpp:241 findDecoder imread_('data/Image_7767.jpg'): can't open/read file: check file path/integrity
# [ WARN:20@5.720] global loadsave.cpp:241 findDecoder imread_('data/Image_9932.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@5.721] global loadsave.cpp:241 findDecoder imread_('data/Image_982.jpg'): can't open/read file: check file path/integrity
# [ WARN:21@5.780] global loadsave.cpp:241 findDecoder imread_('data/Image_9253.jpg'): can't open/read file: check file path/integrity
# [ WARN:2@5.824] global loadsave.cpp:241 findDecoder imread_('data/Image_7757.jpg'): can't open/read file: check file path/integrity
# [ WARN:29@5.842] global loadsave.cpp:241 findDecoder imread_('data/Image_917.jpg'): can't open/read file: check file path/integrity
# [ WARN:17@5.857] global loadsave.cpp:241 findDecoder imread_('data/Image_8691.jpg'): can't open/read file: check file path/integrity
# [ WARN:27@5.863] global loadsave.cpp:241 findDecoder imread_('data/Image_8658.jpg'): can't open/read file: check file path/integrity
# [ WARN:5@5.878] global loadsave.cpp:241 findDecoder imread_('data/Image_9003.jpg'): can't open/read file: check file path/integrity
# [ WARN:5@5.878] global loadsave.cpp:241 findDecoder imread_('data/Image_9986.jpg'): can't open/read file: check file path/integrity
# [ WARN:5@5.881] global loadsave.cpp:241 findDecoder imread_('data/Image_8291.jpg'): can't open/read file: check file path/integrity
# [ WARN:25@5.892] global loadsave.cpp:241 findDecoder imread_('data/Image_9312.jpg'): can't open/read file: check file path/integrity
# [ WARN:25@5.900] global loadsave.cpp:241 findDecoder imread_('data/Image_8216.jpg'): can't open/read file: check file path/integrity
# [ WARN:25@5.900] global loadsave.cpp:241 findDecoder imread_('data/Image_9210.jpg'): can't open/read file: check file path/integrity
# [ WARN:10@5.909] global loadsave.cpp:241 findDecoder imread_('data/Image_8095.jpg'): can't open/read file: check file path/integrity
# [ WARN:10@5.910] global loadsave.cpp:241 findDecoder imread_('data/Image_9076.jpg'): can't open/read file: check file path/integrity
# [ WARN:6@5.915] global loadsave.cpp:241 findDecoder imread_('data/Image_783.jpg'): can't open/read file: check file path/integrity
# [ WARN:12@5.961] global loadsave.cpp:241 findDecoder imread_('data/Image_8109.jpg'): can't open/read file: check file path/integrity
# [ WARN:19@5.970] global loadsave.cpp:241 findDecoder imread_('data/Image_7975.jpg'): can't open/read file: check file path/integrity
# [ WARN:21@6.052] global loadsave.cpp:241 findDecoder imread_('data/Image_9807.jpg'): can't open/read file: check file path/integrity
# [ WARN:21@6.057] global loadsave.cpp:241 findDecoder imread_('data/Image_9246.jpg'): can't open/read file: check file path/integrity
# [ WARN:29@6.152] global loadsave.cpp:241 findDecoder imread_('data/Image_8223.jpg'): can't open/read file: check file path/integrity
# [ WARN:29@6.154] global loadsave.cpp:241 findDecoder imread_('data/Image_9320.jpg'): can't open/read file: check file path/integrity
# [ WARN:6@6.159] global loadsave.cpp:241 findDecoder imread_('data/Image_8433.jpg'): can't open/read file: check file path/integrity
# [ WARN:31@6.191] global loadsave.cpp:241 findDecoder imread_('data/Image_7815.jpg'): can't open/read file: check file path/integrity
# [ WARN:31@6.197] global loadsave.cpp:241 findDecoder imread_('data/Image_8544.jpg'): can't open/read file: check file path/integrity
# [ WARN:11@6.265] global loadsave.cpp:241 findDecoder imread_('data/Image_8015.jpg'): can't open/read file: check file path/integrity
# [ WARN:2@6.270] global loadsave.cpp:241 findDecoder imread_('data/Image_9452.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@6.275] global loadsave.cpp:241 findDecoder imread_('data/Image_8170.jpg'): can't open/read file: check file path/integrity
# [ WARN:1@6.280] global loadsave.cpp:241 findDecoder imread_('data/Image_9449.jpg'): can't open/read file: check file path/integrity
# [ WARN:22@6.426] global loadsave.cpp:241 findDecoder imread_('data/Image_9702.jpg'): can't open/read file: check file path/integrity
# [ WARN:14@6.478] global loadsave.cpp:241 findDecoder imread_('data/Image_8664.jpg'): can't open/read file: check file path/integrity
# [ WARN:6@6.505] global loadsave.cpp:241 findDecoder imread_('data/Image_8271.jpg'): can't open/read file: check file path/integrity
# [ WARN:11@6.557] global loadsave.cpp:241 findDecoder imread_('data/Image_8497.jpg'): can't open/read file: check file path/integrity
# [ WARN:30@6.589] global loadsave.cpp:241 findDecoder imread_('data/Image_7754.jpg'): can't open/read file: check file path/integrity
# [ WARN:15@6.642] global loadsave.cpp:241 findDecoder imread_('data/Image_8518.jpg'): can't open/read file: check file path/integrity
# [ WARN:9@6.674] global loadsave.cpp:241 findDecoder imread_('data/Image_8306.jpg'): can't open/read file: check file path/integrity
# [ WARN:9@6.679] global loadsave.cpp:241 findDecoder imread_('data/Image_8084.jpg'): can't open/read file: check file path/integrity
# [ WARN:3@6.685] global loadsave.cpp:241 findDecoder imread_('data/Image_7964.jpg'): can't open/read file: check file path/integrity
# [ WARN:6@6.750] global loadsave.cpp:241 findDecoder imread_('data/Image_8349.jpg'): can't open/read file: check file path/integrity
# [ WARN:16@6.803] global loadsave.cpp:241 findDecoder imread_('data/Image_9271.jpg'): can't open/read file: check file path/integrity
# [ WARN:17@6.822] global loadsave.cpp:241 findDecoder imread_('data/Image_9691.jpg'): can't open/read file: check file path/integrity
# [ WARN:18@6.880] global loadsave.cpp:241 findDecoder imread_('data/Image_9350.jpg'): can't open/read file: check file path/integrity
# [ WARN:30@6.926] global loadsave.cpp:241 findDecoder imread_('data/Image_9183.jpg'): can't open/read file: check file path/integrity
# [ WARN:9@6.964] global loadsave.cpp:241 findDecoder imread_('data/Image_802.jpg'): can't open/read file: check file path/integrity
# [ WARN:9@6.977] global loadsave.cpp:241 findDecoder imread_('data/Image_7800.jpg'): can't open/read file: check file path/integrity
# [ WARN:6@7.047] global loadsave.cpp:241 findDecoder imread_('data/Image_8537.jpg'): can't open/read file: check file path/integrity
# [ WARN:23@7.054] global loadsave.cpp:241 findDecoder imread_('data/Image_8281.jpg'): can't open/read file: check file path/integrity
# [ WARN:13@7.068] global loadsave.cpp:241 findDecoder imread_('data/Image_8465.jpg'): can't open/read file: check file path/integrity
# [ WARN:7@7.135] global loadsave.cpp:241 findDecoder imread_('data/Image_8241.jpg'): can't open/read file: check file path/integrity
# [ WARN:8@7.144] global loadsave.cpp:241 findDecoder imread_('data/Image_9341.jpg'): can't open/read file: check file path/integrity
# [ WARN:17@7.158] global loadsave.cpp:241 findDecoder imread_('data/Image_9954.jpg'): can't open/read file: check file path/integrity
# [ WARN:29@7.209] global loadsave.cpp:241 findDecoder imread_('data/Image_7736.jpg'): can't open/read file: check file path/integrity
# [ WARN:1@7.266] global loadsave.cpp:241 findDecoder imread_('data/Image_9287.jpg'): can't open/read file: check file path/integrity
# [ WARN:24@7.323] global loadsave.cpp:241 findDecoder imread_('data/Image_9268.jpg'): can't open/read file: check file path/integrity
# [ WARN:24@7.323] global loadsave.cpp:241 findDecoder imread_('data/Image_9279.jpg'): can't open/read file: check file path/integrity
# [ WARN:13@7.328] global loadsave.cpp:241 findDecoder imread_('data/Image_8302.jpg'): can't open/read file: check file path/integrity
# [ WARN:24@7.340] global loadsave.cpp:241 findDecoder imread_('data/Image_8873.jpg'): can't open/read file: check file path/integrity
# [ WARN:11@7.341] global loadsave.cpp:241 findDecoder imread_('data/Image_9239.jpg'): can't open/read file: check file path/integrity
# [ WARN:11@7.342] global loadsave.cpp:241 findDecoder imread_('data/Image_790.jpg'): can't open/read file: check file path/integrity
# [ WARN:7@7.379] global loadsave.cpp:241 findDecoder imread_('data/Image_7895.jpg'): can't open/read file: check file path/integrity
# [ WARN:5@7.411] global loadsave.cpp:241 findDecoder imread_('data/Image_8851.jpg'): can't open/read file: check file path/integrity
# [ WARN:17@7.417] global loadsave.cpp:241 findDecoder imread_('data/Image_9233.jpg'): can't open/read file: check file path/integrity
# [ WARN:17@7.426] global loadsave.cpp:241 findDecoder imread_('data/Image_9293.jpg'): can't open/read file: check file path/integrity
# [ WARN:28@7.460] global loadsave.cpp:241 findDecoder imread_('data/Image_7906.jpg'): can't open/read file: check file path/integrity
# [ WARN:19@7.507] global loadsave.cpp:241 findDecoder imread_('data/Image_9465.jpg'): can't open/read file: check file path/integrity
# [ WARN:23@7.514] global loadsave.cpp:241 findDecoder imread_('data/Image_7950.jpg'): can't open/read file: check file path/integrity
# [ WARN:23@7.515] global loadsave.cpp:241 findDecoder imread_('data/Image_8150.jpg'): can't open/read file: check file path/integrity
# [ WARN:22@7.525] global loadsave.cpp:241 findDecoder imread_('data/Image_9936.jpg'): can't open/read file: check file path/integrity
# [ WARN:22@7.526] global loadsave.cpp:241 findDecoder imread_('data/Image_8484.jpg'): can't open/read file: check file path/integrity
# [ WARN:7@7.642] global loadsave.cpp:241 findDecoder imread_('data/Image_8024.jpg'): can't open/read file: check file path/integrity
# [ WARN:5@7.649] global loadsave.cpp:241 findDecoder imread_('data/Image_9036.jpg'): can't open/read file: check file path/integrity
# [ WARN:18@7.670] global loadsave.cpp:241 findDecoder imread_('data/Image_7766.jpg'): can't open/read file: check file path/integrity
# [ WARN:30@7.681] global loadsave.cpp:241 findDecoder imread_('data/Image_8188.jpg'): can't open/read file: check file path/integrity
# [ WARN:30@7.682] global loadsave.cpp:241 findDecoder imread_('data/Image_8452.jpg'): can't open/read file: check file path/integrity
# [ WARN:12@7.695] global loadsave.cpp:241 findDecoder imread_('data/Image_9055.jpg'): can't open/read file: check file path/integrity
# [ WARN:31@7.837] global loadsave.cpp:241 findDecoder imread_('data/Image_966.jpg'): can't open/read file: check file path/integrity
# [ WARN:26@7.846] global loadsave.cpp:241 findDecoder imread_('data/Image_8813.jpg'): can't open/read file: check file path/integrity
# [ WARN:8@7.858] global loadsave.cpp:241 findDecoder imread_('data/Image_8674.jpg'): can't open/read file: check file path/integrity
# [ WARN:13@7.870] global loadsave.cpp:241 findDecoder imread_('data/Image_873.jpg'): can't open/read file: check file path/integrity
# [ WARN:5@7.875] global loadsave.cpp:241 findDecoder imread_('data/Image_8819.jpg'): can't open/read file: check file path/integrity
# [ WARN:5@7.879] global loadsave.cpp:241 findDecoder imread_('data/Image_9143.jpg'): can't open/read file: check file path/integrity
# [ WARN:4@7.940] global loadsave.cpp:241 findDecoder imread_('data/Image_9995.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@7.956] global loadsave.cpp:241 findDecoder imread_('data/Image_9281.jpg'): can't open/read file: check file path/integrity
# [ WARN:18@7.991] global loadsave.cpp:241 findDecoder imread_('data/Image_9502.jpg'): can't open/read file: check file path/integrity
# [ WARN:9@7.996] global loadsave.cpp:241 findDecoder imread_('data/Image_8673.jpg'): can't open/read file: check file path/integrity
# [ WARN:24@8.059] global loadsave.cpp:241 findDecoder imread_('data/Image_7811.jpg'): can't open/read file: check file path/integrity
# [ WARN:6@8.105] global loadsave.cpp:241 findDecoder imread_('data/Image_7723.jpg'): can't open/read file: check file path/integrity
# [ WARN:27@8.112] global loadsave.cpp:241 findDecoder imread_('data/Image_8264.jpg'): can't open/read file: check file path/integrity
# [ WARN:5@8.127] global loadsave.cpp:241 findDecoder imread_('data/Image_8356.jpg'): can't open/read file: check file path/integrity
# [ WARN:23@8.137] global loadsave.cpp:241 findDecoder imread_('data/Image_9925.jpg'): can't open/read file: check file path/integrity
# [ WARN:23@8.138] global loadsave.cpp:241 findDecoder imread_('data/Image_8391.jpg'): can't open/read file: check file path/integrity
# [ WARN:13@8.152] global loadsave.cpp:241 findDecoder imread_('data/Image_7763.jpg'): can't open/read file: check file path/integrity
# [ WARN:26@8.170] global loadsave.cpp:241 findDecoder imread_('data/Image_8899.jpg'): can't open/read file: check file path/integrity
# [ WARN:26@8.177] global loadsave.cpp:241 findDecoder imread_('data/Image_8474.jpg'): can't open/read file: check file path/integrity
# [ WARN:25@8.208] global loadsave.cpp:241 findDecoder imread_('data/Image_8807.jpg'): can't open/read file: check file path/integrity
# [ WARN:25@8.213] global loadsave.cpp:241 findDecoder imread_('data/Image_9894.jpg'): can't open/read file: check file path/integrity
# [ WARN:24@8.308] global loadsave.cpp:241 findDecoder imread_('data/Image_8775.jpg'): can't open/read file: check file path/integrity
# [ WARN:24@8.308] global loadsave.cpp:241 findDecoder imread_('data/Image_9849.jpg'): can't open/read file: check file path/integrity
# [ WARN:6@8.370] global loadsave.cpp:241 findDecoder imread_('data/Image_8290.jpg'): can't open/read file: check file path/integrity
# [ WARN:1@8.526] global loadsave.cpp:241 findDecoder imread_('data/Image_821.jpg'): can't open/read file: check file path/integrity
# [ WARN:2@8.553] global loadsave.cpp:241 findDecoder imread_('data/Image_7953.jpg'): can't open/read file: check file path/integrity
# [ WARN:24@8.570] global loadsave.cpp:241 findDecoder imread_('data/Image_7875.jpg'): can't open/read file: check file path/integrity
# [ WARN:28@8.604] global loadsave.cpp:241 findDecoder imread_('data/Image_7896.jpg'): can't open/read file: check file path/integrity
# [ WARN:8@8.625] global loadsave.cpp:241 findDecoder imread_('data/Image_8286.jpg'): can't open/read file: check file path/integrity
# [ WARN:26@8.651] global loadsave.cpp:241 findDecoder imread_('data/Image_8369.jpg'): can't open/read file: check file path/integrity
# [ WARN:5@8.746] global loadsave.cpp:241 findDecoder imread_('data/Image_9120.jpg'): can't open/read file: check file path/integrity
# [ WARN:31@8.747] global loadsave.cpp:241 findDecoder imread_('data/Image_9331.jpg'): can't open/read file: check file path/integrity
# [ WARN:11@8.771] global loadsave.cpp:241 findDecoder imread_('data/Image_8911.jpg'): can't open/read file: check file path/integrity
# [ WARN:7@8.920] global loadsave.cpp:241 findDecoder imread_('data/Image_8782.jpg'): can't open/read file: check file path/integrity
# [ WARN:26@9.171] global loadsave.cpp:241 findDecoder imread_('data/Image_8215.jpg'): can't open/read file: check file path/integrity
# [ WARN:6@9.178] global loadsave.cpp:241 findDecoder imread_('data/Image_7945.jpg'): can't open/read file: check file path/integrity
# [ WARN:8@9.198] global loadsave.cpp:241 findDecoder imread_('data/Image_9805.jpg'): can't open/read file: check file path/integrity
# [ WARN:23@9.319] global loadsave.cpp:241 findDecoder imread_('data/Image_9910.jpg'): can't open/read file: check file path/integrity
# [ WARN:12@9.335] global loadsave.cpp:241 findDecoder imread_('data/Image_7803.jpg'): can't open/read file: check file path/integrity
# [ WARN:12@9.335] global loadsave.cpp:241 findDecoder imread_('data/Image_9301.jpg'): can't open/read file: check file path/integrity
# [ WARN:12@9.336] global loadsave.cpp:241 findDecoder imread_('data/Image_9725.jpg'): can't open/read file: check file path/integrity
# [ WARN:19@9.366] global loadsave.cpp:241 findDecoder imread_('data/Image_8875.jpg'): can't open/read file: check file path/integrity
# [ WARN:8@9.426] global loadsave.cpp:241 findDecoder imread_('data/Image_9485.jpg'): can't open/read file: check file path/integrity
# [ WARN:2@9.517] global loadsave.cpp:241 findDecoder imread_('data/Image_8682.jpg'): can't open/read file: check file path/integrity
# [ WARN:13@9.521] global loadsave.cpp:241 findDecoder imread_('data/Image_9171.jpg'): can't open/read file: check file path/integrity
# [ WARN:13@9.541] global loadsave.cpp:241 findDecoder imread_('data/Image_9292.jpg'): can't open/read file: check file path/integrity
# [ WARN:23@9.577] global loadsave.cpp:241 findDecoder imread_('data/Image_9403.jpg'): can't open/read file: check file path/integrity
# [ WARN:16@9.599] global loadsave.cpp:241 findDecoder imread_('data/Image_9697.jpg'): can't open/read file: check file path/integrity
# [ WARN:30@9.609] global loadsave.cpp:241 findDecoder imread_('data/Image_838.jpg'): can't open/read file: check file path/integrity
# [ WARN:9@9.615] global loadsave.cpp:241 findDecoder imread_('data/Image_9060.jpg'): can't open/read file: check file path/integrity
# [ WARN:19@9.636] global loadsave.cpp:241 findDecoder imread_('data/Image_9659.jpg'): can't open/read file: check file path/integrity
# [ WARN:22@9.726] global loadsave.cpp:241 findDecoder imread_('data/Image_7982.jpg'): can't open/read file: check file path/integrity
# [ WARN:7@9.782] global loadsave.cpp:241 findDecoder imread_('data/Image_8006.jpg'): can't open/read file: check file path/integrity
# [ WARN:13@9.800] global loadsave.cpp:241 findDecoder imread_('data/Image_8872.jpg'): can't open/read file: check file path/integrity
# [ WARN:25@9.805] global loadsave.cpp:241 findDecoder imread_('data/Image_9408.jpg'): can't open/read file: check file path/integrity
# [ WARN:31@9.834] global loadsave.cpp:241 findDecoder imread_('data/Image_9929.jpg'): can't open/read file: check file path/integrity
# [ WARN:14@9.928] global loadsave.cpp:241 findDecoder imread_('data/Image_8642.jpg'): can't open/read file: check file path/integrity
# [ WARN:21@9.938] global loadsave.cpp:241 findDecoder imread_('data/Image_9927.jpg'): can't open/read file: check file path/integrity
# [ WARN:18@9.969] global loadsave.cpp:241 findDecoder imread_('data/Image_9585.jpg'): can't open/read file: check file path/integrity
# [ WARN:8@9.977] global loadsave.cpp:241 findDecoder imread_('data/Image_8815.jpg'): can't open/read file: check file path/integrity
# [ WARN:5@10.016] global loadsave.cpp:241 findDecoder imread_('data/Image_8359.jpg'): can't open/read file: check file path/integrity
# [ WARN:26@10.029] global loadsave.cpp:241 findDecoder imread_('data/Image_7887.jpg'): can't open/read file: check file path/integrity
# [ WARN:7@10.074] global loadsave.cpp:241 findDecoder imread_('data/Image_9843.jpg'): can't open/read file: check file path/integrity
# [ WARN:13@10.117] global loadsave.cpp:241 findDecoder imread_('data/Image_8178.jpg'): can't open/read file: check file path/integrity
# [ WARN:23@10.151] global loadsave.cpp:241 findDecoder imread_('data/Image_8114.jpg'): can't open/read file: check file path/integrity
# [ WARN:16@10.170] global loadsave.cpp:241 findDecoder imread_('data/Image_7799.jpg'): can't open/read file: check file path/integrity
# [ WARN:16@10.172] global loadsave.cpp:241 findDecoder imread_('data/Image_9595.jpg'): can't open/read file: check file path/integrity
# [ WARN:6@10.235] global loadsave.cpp:241 findDecoder imread_('data/Image_8048.jpg'): can't open/read file: check file path/integrity
# [ WARN:26@10.242] global loadsave.cpp:241 findDecoder imread_('data/Image_8671.jpg'): can't open/read file: check file path/integrity
# [ WARN:5@10.287] global loadsave.cpp:241 findDecoder imread_('data/Image_9983.jpg'): can't open/read file: check file path/integrity
# [ WARN:12@10.371] global loadsave.cpp:241 findDecoder imread_('data/Image_8848.jpg'): can't open/read file: check file path/integrity
# [ WARN:12@10.374] global loadsave.cpp:241 findDecoder imread_('data/Image_8865.jpg'): can't open/read file: check file path/integrity
# [ WARN:22@10.511] global loadsave.cpp:241 findDecoder imread_('data/Image_9599.jpg'): can't open/read file: check file path/integrity
# [ WARN:22@10.513] global loadsave.cpp:241 findDecoder imread_('data/Image_9892.jpg'): can't open/read file: check file path/integrity
# [ WARN:7@10.572] global loadsave.cpp:241 findDecoder imread_('data/Image_810.jpg'): can't open/read file: check file path/integrity
# [ WARN:7@10.573] global loadsave.cpp:241 findDecoder imread_('data/Image_9266.jpg'): can't open/read file: check file path/integrity
# [ WARN:29@10.606] global loadsave.cpp:241 findDecoder imread_('data/Image_8480.jpg'): can't open/read file: check file path/integrity
# [ WARN:29@10.607] global loadsave.cpp:241 findDecoder imread_('data/Image_9804.jpg'): can't open/read file: check file path/integrity
# [ WARN:9@10.617] global loadsave.cpp:241 findDecoder imread_('data/Image_7812.jpg'): can't open/read file: check file path/integrity
# [ WARN:22@10.780] global loadsave.cpp:241 findDecoder imread_('data/Image_8877.jpg'): can't open/read file: check file path/integrity
# [ WARN:8@10.792] global loadsave.cpp:241 findDecoder imread_('data/Image_9537.jpg'): can't open/read file: check file path/integrity
# [ WARN:20@10.805] global loadsave.cpp:241 findDecoder imread_('data/Image_8830.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@10.830] global loadsave.cpp:241 findDecoder imread_('data/Image_8699.jpg'): can't open/read file: check file path/integrity
# [ WARN:30@10.936] global loadsave.cpp:241 findDecoder imread_('data/Image_7745.jpg'): can't open/read file: check file path/integrity
# [ WARN:19@10.951] global loadsave.cpp:241 findDecoder imread_('data/Image_8949.jpg'): can't open/read file: check file path/integrity
# [ WARN:21@11.003] global loadsave.cpp:241 findDecoder imread_('data/Image_8676.jpg'): can't open/read file: check file path/integrity
# [ WARN:21@11.005] global loadsave.cpp:241 findDecoder imread_('data/Image_9232.jpg'): can't open/read file: check file path/integrity
# [ WARN:7@11.050] global loadsave.cpp:241 findDecoder imread_('data/Image_9448.jpg'): can't open/read file: check file path/integrity
# [ WARN:3@11.097] global loadsave.cpp:241 findDecoder imread_('data/Image_9395.jpg'): can't open/read file: check file path/integrity
# [ WARN:11@11.114] global loadsave.cpp:241 findDecoder imread_('data/Image_8456.jpg'): can't open/read file: check file path/integrity
# [ WARN:11@11.117] global loadsave.cpp:241 findDecoder imread_('data/Image_7825.jpg'): can't open/read file: check file path/integrity
# [ WARN:27@11.122] global loadsave.cpp:241 findDecoder imread_('data/Image_9649.jpg'): can't open/read file: check file path/integrity
# [ WARN:27@11.135] global loadsave.cpp:241 findDecoder imread_('data/Image_8961.jpg'): can't open/read file: check file path/integrity
# [ WARN:27@11.135] global loadsave.cpp:241 findDecoder imread_('data/Image_8560.jpg'): can't open/read file: check file path/integrity
# [ WARN:29@11.150] global loadsave.cpp:241 findDecoder imread_('data/Image_843.jpg'): can't open/read file: check file path/integrity
# [ WARN:24@11.195] global loadsave.cpp:241 findDecoder imread_('data/Image_8396.jpg'): can't open/read file: check file path/integrity
# [ WARN:24@11.196] global loadsave.cpp:241 findDecoder imread_('data/Image_9476.jpg'): can't open/read file: check file path/integrity
# [ WARN:24@11.197] global loadsave.cpp:241 findDecoder imread_('data/Image_8898.jpg'): can't open/read file: check file path/integrity
# [ WARN:21@11.257] global loadsave.cpp:241 findDecoder imread_('data/Image_9025.jpg'): can't open/read file: check file path/integrity
# [ WARN:13@11.304] global loadsave.cpp:241 findDecoder imread_('data/Image_8167.jpg'): can't open/read file: check file path/integrity
# [ WARN:3@11.349] global loadsave.cpp:241 findDecoder imread_('data/Image_7732.jpg'): can't open/read file: check file path/integrity
# [ WARN:2@11.371] global loadsave.cpp:241 findDecoder imread_('data/Image_7838.jpg'): can't open/read file: check file path/integrity
# [ WARN:25@11.382] global loadsave.cpp:241 findDecoder imread_('data/Image_7891.jpg'): can't open/read file: check file path/integrity
# [ WARN:28@11.392] global loadsave.cpp:241 findDecoder imread_('data/Image_907.jpg'): can't open/read file: check file path/integrity
# [ WARN:31@11.401] global loadsave.cpp:241 findDecoder imread_('data/Image_8470.jpg'): can't open/read file: check file path/integrity
# [ WARN:28@11.401] global loadsave.cpp:241 findDecoder imread_('data/Image_9001.jpg'): can't open/read file: check file path/integrity
# [ WARN:9@11.453] global loadsave.cpp:241 findDecoder imread_('data/Image_9382.jpg'): can't open/read file: check file path/integrity
# [ WARN:14@11.487] global loadsave.cpp:241 findDecoder imread_('data/Image_9742.jpg'): can't open/read file: check file path/integrity
# [ WARN:2@11.624] global loadsave.cpp:241 findDecoder imread_('data/Image_9515.jpg'): can't open/read file: check file path/integrity
# [ WARN:25@11.629] global loadsave.cpp:241 findDecoder imread_('data/Image_8843.jpg'): can't open/read file: check file path/integrity
# [ WARN:2@11.636] global loadsave.cpp:241 findDecoder imread_('data/Image_8745.jpg'): can't open/read file: check file path/integrity
# [ WARN:17@11.654] global loadsave.cpp:241 findDecoder imread_('data/Image_8070.jpg'): can't open/read file: check file path/integrity
# [ WARN:19@11.710] global loadsave.cpp:241 findDecoder imread_('data/Image_8930.jpg'): can't open/read file: check file path/integrity
# [ WARN:9@11.722] global loadsave.cpp:241 findDecoder imread_('data/Image_8110.jpg'): can't open/read file: check file path/integrity
# [ WARN:1@11.740] global loadsave.cpp:241 findDecoder imread_('data/Image_8803.jpg'): can't open/read file: check file path/integrity
# [ WARN:1@11.742] global loadsave.cpp:241 findDecoder imread_('data/Image_8040.jpg'): can't open/read file: check file path/integrity
# [ WARN:13@11.848] global loadsave.cpp:241 findDecoder imread_('data/Image_9933.jpg'): can't open/read file: check file path/integrity
# [ WARN:20@11.860] global loadsave.cpp:241 findDecoder imread_('data/Image_8442.jpg'): can't open/read file: check file path/integrity
# [ WARN:25@11.928] global loadsave.cpp:241 findDecoder imread_('data/Image_8282.jpg'): can't open/read file: check file path/integrity
# [ WARN:24@11.980] global loadsave.cpp:241 findDecoder imread_('data/Image_793.jpg'): can't open/read file: check file path/integrity
# [ WARN:29@12.007] global loadsave.cpp:241 findDecoder imread_('data/Image_9631.jpg'): can't open/read file: check file path/integrity
# [ WARN:14@12.038] global loadsave.cpp:241 findDecoder imread_('data/Image_7727.jpg'): can't open/read file: check file path/integrity
# [ WARN:7@12.044] global loadsave.cpp:241 findDecoder imread_('data/Image_8279.jpg'): can't open/read file: check file path/integrity
# [ WARN:5@12.056] global loadsave.cpp:241 findDecoder imread_('data/Image_8431.jpg'): can't open/read file: check file path/integrity
# [ WARN:1@12.061] global loadsave.cpp:241 findDecoder imread_('data/Image_872.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@12.080] global loadsave.cpp:241 findDecoder imread_('data/Image_9203.jpg'): can't open/read file: check file path/integrity
# [ WARN:4@12.130] global loadsave.cpp:241 findDecoder imread_('data/Image_7909.jpg'): can't open/read file: check file path/integrity
# [ WARN:15@12.138] global loadsave.cpp:241 findDecoder imread_('data/Image_7810.jpg'): can't open/read file: check file path/integrity
# [ WARN:13@12.154] global loadsave.cpp:241 findDecoder imread_('data/Image_7904.jpg'): can't open/read file: check file path/integrity
# [ WARN:22@12.166] global loadsave.cpp:241 findDecoder imread_('data/Image_7749.jpg'): can't open/read file: check file path/integrity
# [ WARN:25@12.179] global loadsave.cpp:241 findDecoder imread_('data/Image_9625.jpg'): can't open/read file: check file path/integrity
# [ WARN:11@12.185] global loadsave.cpp:241 findDecoder imread_('data/Image_8012.jpg'): can't open/read file: check file path/integrity
# [ WARN:17@12.236] global loadsave.cpp:241 findDecoder imread_('data/Image_8404.jpg'): can't open/read file: check file path/integrity
# [ WARN:17@12.236] global loadsave.cpp:241 findDecoder imread_('data/Image_8611.jpg'): can't open/read file: check file path/integrity
# [ WARN:24@12.242] global loadsave.cpp:241 findDecoder imread_('data/Image_8062.jpg'): can't open/read file: check file path/integrity
# [ WARN:18@12.354] global loadsave.cpp:241 findDecoder imread_('data/Image_8887.jpg'): can't open/read file: check file path/integrity
# [ WARN:25@12.480] global loadsave.cpp:241 findDecoder imread_('data/Image_8373.jpg'): can't open/read file: check file path/integrity
# [ WARN:25@12.481] global loadsave.cpp:241 findDecoder imread_('data/Image_8861.jpg'): can't open/read file: check file path/integrity
# [ WARN:25@12.487] global loadsave.cpp:241 findDecoder imread_('data/Image_8224.jpg'): can't open/read file: check file path/integrity
# [ WARN:12@12.543] global loadsave.cpp:241 findDecoder imread_('data/Image_8797.jpg'): can't open/read file: check file path/integrity
# [ WARN:20@12.690] global loadsave.cpp:241 findDecoder imread_('data/Image_935.jpg'): can't open/read file: check file path/integrity
# [ WARN:13@12.714] global loadsave.cpp:241 findDecoder imread_('data/Image_8654.jpg'): can't open/read file: check file path/integrity
# [ WARN:27@12.760] global loadsave.cpp:241 findDecoder imread_('data/Image_9989.jpg'): can't open/read file: check file path/integrity
# [ WARN:16@12.785] global loadsave.cpp:241 findDecoder imread_('data/Image_8421.jpg'): can't open/read file: check file path/integrity
# [ WARN:16@12.788] global loadsave.cpp:241 findDecoder imread_('data/Image_9629.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@12.853] global loadsave.cpp:241 findDecoder imread_('data/Image_9845.jpg'): can't open/read file: check file path/integrity
# [ WARN:29@13.019] global loadsave.cpp:241 findDecoder imread_('data/Image_8208.jpg'): can't open/read file: check file path/integrity
# [ WARN:29@13.020] global loadsave.cpp:241 findDecoder imread_('data/Image_8646.jpg'): can't open/read file: check file path/integrity
# [ WARN:12@13.066] global loadsave.cpp:241 findDecoder imread_('data/Image_9138.jpg'): can't open/read file: check file path/integrity
# [ WARN:11@13.236] global loadsave.cpp:241 findDecoder imread_('data/Image_9782.jpg'): can't open/read file: check file path/integrity
# [ WARN:17@13.308] global loadsave.cpp:241 findDecoder imread_('data/Image_8295.jpg'): can't open/read file: check file path/integrity
# [ WARN:17@13.324] global loadsave.cpp:241 findDecoder imread_('data/Image_8022.jpg'): can't open/read file: check file path/integrity
# [ WARN:28@13.357] global loadsave.cpp:241 findDecoder imread_('data/Image_8445.jpg'): can't open/read file: check file path/integrity
# [ WARN:14@13.364] global loadsave.cpp:241 findDecoder imread_('data/Image_859.jpg'): can't open/read file: check file path/integrity
# [ WARN:14@13.366] global loadsave.cpp:241 findDecoder imread_('data/Image_842.jpg'): can't open/read file: check file path/integrity
# ...
# [ WARN:73@87.974] global loadsave.cpp:241 findDecoder imread_('data/Image_8529.jpg'): can't open/read file: check file path/integrity
# [ WARN:73@87.976] global loadsave.cpp:241 findDecoder imread_('data/Image_8288.jpg'): can't open/read file: check file path/integrity
# [ WARN:73@87.983] global loadsave.cpp:241 findDecoder imread_('data/Image_9101.jpg'): can't open/read file: check file path/integrity
# [ WARN:83@88.004] global loadsave.cpp:241 findDecoder imread_('data/Image_9262.jpg'): can't open/read file: check file path/integrity
# [ WARN:64@88.016] global loadsave.cpp:241 findDecoder imread_('data/Image_8559.jpg'): can't open/read file: check file path/integrity
# [ WARN:66@88.028] global loadsave.cpp:241 findDecoder imread_('data/Image_8401.jpg'): can't open/read file: check file path/integrity
# [ WARN:93@88.057] global loadsave.cpp:241 findDecoder imread_('data/Image_922.jpg'): can't open/read file: check file path/integrity
# [ WARN:71@88.065] global loadsave.cpp:241 findDecoder imread_('data/Image_867.jpg'): can't open/read file: check file path/integrity
# [ WARN:68@88.089] global loadsave.cpp:241 findDecoder imread_('data/Image_8238.jpg'): can't open/read file: check file path/integrity
# [ WARN:69@88.134] global loadsave.cpp:241 findDecoder imread_('data/Image_8422.jpg'): can't open/read file: check file path/integrity
# [ WARN:80@88.152] global loadsave.cpp:241 findDecoder imread_('data/Image_8381.jpg'): can't open/read file: check file path/integrity
# [ WARN:86@88.158] global loadsave.cpp:241 findDecoder imread_('data/Image_9900.jpg'): can't open/read file: check file path/integrity
# [ WARN:86@88.158] global loadsave.cpp:241 findDecoder imread_('data/Image_9327.jpg'): can't open/read file: check file path/integrity
# [ WARN:83@88.254] global loadsave.cpp:241 findDecoder imread_('data/Image_796.jpg'): can't open/read file: check file path/integrity
# [ WARN:66@88.302] global loadsave.cpp:241 findDecoder imread_('data/Image_9038.jpg'): can't open/read file: check file path/integrity
# [ WARN:69@88.377] global loadsave.cpp:241 findDecoder imread_('data/Image_8053.jpg'): can't open/read file: check file path/integrity
# [ WARN:92@88.494] global loadsave.cpp:241 findDecoder imread_('data/Image_8412.jpg'): can't open/read file: check file path/integrity
# [ WARN:66@88.500] global loadsave.cpp:241 findDecoder imread_('data/Image_9057.jpg'): can't open/read file: check file path/integrity
# [ WARN:66@88.506] global loadsave.cpp:241 findDecoder imread_('data/Image_8893.jpg'): can't open/read file: check file path/integrity
# [ WARN:79@88.540] global loadsave.cpp:241 findDecoder imread_('data/Image_9784.jpg'): can't open/read file: check file path/integrity
# [ WARN:64@88.568] global loadsave.cpp:241 findDecoder imread_('data/Image_797.jpg'): can't open/read file: check file path/integrity
# [ WARN:93@88.593] global loadsave.cpp:241 findDecoder imread_('data/Image_9471.jpg'): can't open/read file: check file path/integrity
# [ WARN:93@88.593] global loadsave.cpp:241 findDecoder imread_('data/Image_8704.jpg'): can't open/read file: check file path/integrity
# [ WARN:94@88.814] global loadsave.cpp:241 findDecoder imread_('data/Image_9600.jpg'): can't open/read file: check file path/integrity
# [ WARN:64@88.835] global loadsave.cpp:241 findDecoder imread_('data/Image_9237.jpg'): can't open/read file: check file path/integrity
# [ WARN:79@88.855] global loadsave.cpp:241 findDecoder imread_('data/Image_9566.jpg'): can't open/read file: check file path/integrity
# [ WARN:79@88.869] global loadsave.cpp:241 findDecoder imread_('data/Image_961.jpg'): can't open/read file: check file path/integrity
# [ WARN:68@88.870] global loadsave.cpp:241 findDecoder imread_('data/Image_8270.jpg'): can't open/read file: check file path/integrity
# [ WARN:68@88.878] global loadsave.cpp:241 findDecoder imread_('data/Image_884.jpg'): can't open/read file: check file path/integrity
# [ WARN:68@88.880] global loadsave.cpp:241 findDecoder imread_('data/Image_8258.jpg'): can't open/read file: check file path/integrity
# [ WARN:91@88.898] global loadsave.cpp:241 findDecoder imread_('data/Image_8618.jpg'): can't open/read file: check file path/integrity
# [ WARN:93@88.906] global loadsave.cpp:241 findDecoder imread_('data/Image_9882.jpg'): can't open/read file: check file path/integrity
# [ WARN:93@88.906] global loadsave.cpp:241 findDecoder imread_('data/Image_8913.jpg'): can't open/read file: check file path/integrity
# [ WARN:77@88.939] global loadsave.cpp:241 findDecoder imread_('data/Image_9879.jpg'): can't open/read file: check file path/integrity
# [ WARN:90@88.992] global loadsave.cpp:241 findDecoder imread_('data/Image_8510.jpg'): can't open/read file: check file path/integrity
# [ WARN:65@89.054] global loadsave.cpp:241 findDecoder imread_('data/Image_8725.jpg'): can't open/read file: check file path/integrity
# [ WARN:83@89.106] global loadsave.cpp:241 findDecoder imread_('data/Image_8242.jpg'): can't open/read file: check file path/integrity
# [ WARN:74@89.142] global loadsave.cpp:241 findDecoder imread_('data/Image_7937.jpg'): can't open/read file: check file path/integrity
# [ WARN:67@89.175] global loadsave.cpp:241 findDecoder imread_('data/Image_8068.jpg'): can't open/read file: check file path/integrity
# [ WARN:93@89.213] global loadsave.cpp:241 findDecoder imread_('data/Image_9771.jpg'): can't open/read file: check file path/integrity
# [ WARN:80@89.223] global loadsave.cpp:241 findDecoder imread_('data/Image_7918.jpg'): can't open/read file: check file path/integrity
# [ WARN:93@89.226] global loadsave.cpp:241 findDecoder imread_('data/Image_8303.jpg'): can't open/read file: check file path/integrity
# [ WARN:84@89.285] global loadsave.cpp:241 findDecoder imread_('data/Image_9086.jpg'): can't open/read file: check file path/integrity
# [ WARN:89@89.301] global loadsave.cpp:241 findDecoder imread_('data/Image_9871.jpg'): can't open/read file: check file path/integrity
# [ WARN:89@89.317] global loadsave.cpp:241 findDecoder imread_('data/Image_9490.jpg'): can't open/read file: check file path/integrity
# [ WARN:76@89.345] global loadsave.cpp:241 findDecoder imread_('data/Image_9337.jpg'): can't open/read file: check file path/integrity
# [ WARN:72@89.459] global loadsave.cpp:241 findDecoder imread_('data/Image_9635.jpg'): can't open/read file: check file path/integrity
# [ WARN:67@89.488] global loadsave.cpp:241 findDecoder imread_('data/Image_8883.jpg'): can't open/read file: check file path/integrity
# [ WARN:91@89.497] global loadsave.cpp:241 findDecoder imread_('data/Image_8217.jpg'): can't open/read file: check file path/integrity
# [ WARN:67@89.498] global loadsave.cpp:241 findDecoder imread_('data/Image_8169.jpg'): can't open/read file: check file path/integrity
# [ WARN:90@89.505] global loadsave.cpp:241 findDecoder imread_('data/Image_9934.jpg'): can't open/read file: check file path/integrity
# [ WARN:81@89.529] global loadsave.cpp:241 findDecoder imread_('data/Image_8789.jpg'): can't open/read file: check file path/integrity
# [ WARN:66@89.566] global loadsave.cpp:241 findDecoder imread_('data/Image_8185.jpg'): can't open/read file: check file path/integrity
# [ WARN:76@89.634] global loadsave.cpp:241 findDecoder imread_('data/Image_7760.jpg'): can't open/read file: check file path/integrity
# [ WARN:64@89.670] global loadsave.cpp:241 findDecoder imread_('data/Image_9821.jpg'): can't open/read file: check file path/integrity
# [ WARN:80@89.719] global loadsave.cpp:241 findDecoder imread_('data/Image_7744.jpg'): can't open/read file: check file path/integrity
# [ WARN:93@89.731] global loadsave.cpp:241 findDecoder imread_('data/Image_9114.jpg'): can't open/read file: check file path/integrity
# [ WARN:91@89.743] global loadsave.cpp:241 findDecoder imread_('data/Image_7924.jpg'): can't open/read file: check file path/integrity
# [ WARN:91@89.753] global loadsave.cpp:241 findDecoder imread_('data/Image_8524.jpg'): can't open/read file: check file path/integrity
# [ WARN:91@89.758] global loadsave.cpp:241 findDecoder imread_('data/Image_9692.jpg'): can't open/read file: check file path/integrity
# [ WARN:93@89.764] global loadsave.cpp:241 findDecoder imread_('data/Image_9972.jpg'): can't open/read file: check file path/integrity
# [ WARN:69@89.788] global loadsave.cpp:241 findDecoder imread_('data/Image_7912.jpg'): can't open/read file: check file path/integrity
# [ WARN:70@89.859] global loadsave.cpp:241 findDecoder imread_('data/Image_953.jpg'): can't open/read file: check file path/integrity
# [ WARN:73@89.908] global loadsave.cpp:241 findDecoder imread_('data/Image_8662.jpg'): can't open/read file: check file path/integrity
# [ WARN:74@89.919] global loadsave.cpp:241 findDecoder imread_('data/Image_9342.jpg'): can't open/read file: check file path/integrity
# [ WARN:73@89.920] global loadsave.cpp:241 findDecoder imread_('data/Image_8701.jpg'): can't open/read file: check file path/integrity
# [ WARN:77@89.947] global loadsave.cpp:241 findDecoder imread_('data/Image_9193.jpg'): can't open/read file: check file path/integrity
# [ WARN:77@89.947] global loadsave.cpp:241 findDecoder imread_('data/Image_9397.jpg'): can't open/read file: check file path/integrity
# [ WARN:77@89.948] global loadsave.cpp:241 findDecoder imread_('data/Image_9481.jpg'): can't open/read file: check file path/integrity
# [ WARN:80@90.012] global loadsave.cpp:241 findDecoder imread_('data/Image_8566.jpg'): can't open/read file: check file path/integrity
# [ WARN:80@90.026] global loadsave.cpp:241 findDecoder imread_('data/Image_97.jpg'): can't open/read file: check file path/integrity
# [ WARN:88@90.060] global loadsave.cpp:241 findDecoder imread_('data/Image_8891.jpg'): can't open/read file: check file path/integrity
# [ WARN:81@90.100] global loadsave.cpp:241 findDecoder imread_('data/Image_8426.jpg'): can't open/read file: check file path/integrity
# [ WARN:77@90.189] global loadsave.cpp:241 findDecoder imread_('data/Image_8686.jpg'): can't open/read file: check file path/integrity
# [ WARN:65@90.198] global loadsave.cpp:241 findDecoder imread_('data/Image_9737.jpg'): can't open/read file: check file path/integrity
# [ WARN:76@90.209] global loadsave.cpp:241 findDecoder imread_('data/Image_89.jpg'): can't open/read file: check file path/integrity
# [ WARN:65@90.211] global loadsave.cpp:241 findDecoder imread_('data/Image_7916.jpg'): can't open/read file: check file path/integrity
# [ WARN:67@90.277] global loadsave.cpp:241 findDecoder imread_('data/Image_8785.jpg'): can't open/read file: check file path/integrity
# [ WARN:69@90.319] global loadsave.cpp:241 findDecoder imread_('data/Image_8249.jpg'): can't open/read file: check file path/integrity
# [ WARN:79@90.354] global loadsave.cpp:241 findDecoder imread_('data/Image_8909.jpg'): can't open/read file: check file path/integrity
# [ WARN:81@90.406] global loadsave.cpp:241 findDecoder imread_('data/Image_8574.jpg'): can't open/read file: check file path/integrity
# [ WARN:81@90.420] global loadsave.cpp:241 findDecoder imread_('data/Image_8905.jpg'): can't open/read file: check file path/integrity
# [ WARN:85@90.580] global loadsave.cpp:241 findDecoder imread_('data/Image_9389.jpg'): can't open/read file: check file path/integrity
# [ WARN:89@90.611] global loadsave.cpp:241 findDecoder imread_('data/Image_9695.jpg'): can't open/read file: check file path/integrity
# [ WARN:70@90.615] global loadsave.cpp:241 findDecoder imread_('data/Image_9330.jpg'): can't open/read file: check file path/integrity
# [ WARN:89@90.623] global loadsave.cpp:241 findDecoder imread_('data/Image_775.jpg'): can't open/read file: check file path/integrity
# [ WARN:82@90.641] global loadsave.cpp:241 findDecoder imread_('data/Image_8413.jpg'): can't open/read file: check file path/integrity
# [ WARN:69@90.676] global loadsave.cpp:241 findDecoder imread_('data/Image_8977.jpg'): can't open/read file: check file path/integrity
# [ WARN:83@90.684] global loadsave.cpp:241 findDecoder imread_('data/Image_8599.jpg'): can't open/read file: check file path/integrity
# [ WARN:76@90.756] global loadsave.cpp:241 findDecoder imread_('data/Image_80.jpg'): can't open/read file: check file path/integrity
# [ WARN:89@90.841] global loadsave.cpp:241 findDecoder imread_('data/Image_9059.jpg'): can't open/read file: check file path/integrity
# [ WARN:65@90.955] global loadsave.cpp:241 findDecoder imread_('data/Image_8726.jpg'): can't open/read file: check file path/integrity
# [ WARN:65@90.956] global loadsave.cpp:241 findDecoder imread_('data/Image_853.jpg'): can't open/read file: check file path/integrity
# [ WARN:63@91.029] global loadsave.cpp:241 findDecoder imread_('data/Image_8139.jpg'): can't open/read file: check file path/integrity
# [ WARN:85@91.153] global loadsave.cpp:241 findDecoder imread_('data/Image_7894.jpg'): can't open/read file: check file path/integrity
# [ WARN:85@91.153] global loadsave.cpp:241 findDecoder imread_('data/Image_9723.jpg'): can't open/read file: check file path/integrity
# [ WARN:82@91.160] global loadsave.cpp:241 findDecoder imread_('data/Image_8966.jpg'): can't open/read file: check file path/integrity
# [ WARN:91@91.170] global loadsave.cpp:241 findDecoder imread_('data/Image_9820.jpg'): can't open/read file: check file path/integrity
# [ WARN:81@91.220] global loadsave.cpp:241 findDecoder imread_('data/Image_9896.jpg'): can't open/read file: check file path/integrity
# [ WARN:81@91.221] global loadsave.cpp:241 findDecoder imread_('data/Image_778.jpg'): can't open/read file: check file path/integrity
# [ WARN:79@91.264] global loadsave.cpp:241 findDecoder imread_('data/Image_8582.jpg'): can't open/read file: check file path/integrity
# [ WARN:77@91.272] global loadsave.cpp:241 findDecoder imread_('data/Image_9684.jpg'): can't open/read file: check file path/integrity
# [ WARN:68@91.278] global loadsave.cpp:241 findDecoder imread_('data/Image_8186.jpg'): can't open/read file: check file path/integrity
# [ WARN:72@91.313] global loadsave.cpp:241 findDecoder imread_('data/Image_9113.jpg'): can't open/read file: check file path/integrity
# [ WARN:89@91.502] global loadsave.cpp:241 findDecoder imread_('data/Image_8688.jpg'): can't open/read file: check file path/integrity
# [ WARN:89@91.503] global loadsave.cpp:241 findDecoder imread_('data/Image_8345.jpg'): can't open/read file: check file path/integrity
# [ WARN:75@91.512] global loadsave.cpp:241 findDecoder imread_('data/Image_8132.jpg'): can't open/read file: check file path/integrity
# [ WARN:81@91.533] global loadsave.cpp:241 findDecoder imread_('data/Image_9862.jpg'): can't open/read file: check file path/integrity
# [ WARN:71@91.572] global loadsave.cpp:241 findDecoder imread_('data/Image_9400.jpg'): can't open/read file: check file path/integrity
# [ WARN:87@91.592] global loadsave.cpp:241 findDecoder imread_('data/Image_9864.jpg'): can't open/read file: check file path/integrity
# [ WARN:83@91.606] global loadsave.cpp:241 findDecoder imread_('data/Image_8038.jpg'): can't open/read file: check file path/integrity
# [ WARN:90@91.743] global loadsave.cpp:241 findDecoder imread_('data/Image_9895.jpg'): can't open/read file: check file path/integrity
# [ WARN:90@91.763] global loadsave.cpp:241 findDecoder imread_('data/Image_81.jpg'): can't open/read file: check file path/integrity
# [ WARN:94@91.826] global loadsave.cpp:241 findDecoder imread_('data/Image_8619.jpg'): can't open/read file: check file path/integrity
# [ WARN:68@91.831] global loadsave.cpp:241 findDecoder imread_('data/Image_880.jpg'): can't open/read file: check file path/integrity
# [ WARN:63@91.879] global loadsave.cpp:241 findDecoder imread_('data/Image_9225.jpg'): can't open/read file: check file path/integrity
# [ WARN:63@91.879] global loadsave.cpp:241 findDecoder imread_('data/Image_9181.jpg'): can't open/read file: check file path/integrity
# [ WARN:86@91.886] global loadsave.cpp:241 findDecoder imread_('data/Image_9648.jpg'): can't open/read file: check file path/integrity
# [ WARN:73@91.962] global loadsave.cpp:241 findDecoder imread_('data/Image_7776.jpg'): can't open/read file: check file path/integrity

# %%
print(X_train.shape)
print(X_test.shape)
print(train_features.shape)
print(test_features.shape)
# Out:
# (10080,)
# (2520,)
# (8063, 10063)
# (2009, 10063)

# %%
# Apply PCA only on the training data to avoid data leakage
pca = PCA(n_components=250)  # Adjust the number of components as needed

# Normalize features using StandardScaler
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train_features)
X_test_scaled = scaler.transform(X_test_features)

X_train_pca = pca.fit_transform(X_train_scaled)
X_test_pca = pca.transform(X_test_scaled)

# %%
best_rf_params = {
    "n_estimators": 1000,
    "min_samples_split": 10,
    "max_features":'sqrt',
    "max_depth":30,
    "random_state": 42,
    "n_jobs": -1

}

rf = RandomForestClassifier(**best_rf_params)
rf.fit(X_train_pca, y_train_labels)

# Test the model
y_pred = rf.predict(X_test_pca)
accuracy = accuracy_score(y_test_labels, y_pred)
print(f"Random Forest Model Accuracy: {accuracy:.4f}")
# Out:
# Random Forest Model Accuracy: 0.3225

# %%
model_filename = 'trained_random_forest_model.pkl'
with open(model_filename, 'wb') as file:
    pickle.dump(rf, file)

# %%
# Create a pipeline with imputation and Naive Bayes
pipeline = Pipeline([
    ('imputer', SimpleImputer(strategy='mean')),  # Impute missing values
    ('nb', GaussianNB())
])

# Train the model
pipeline.fit(X_train_pca, y_train_labels)

# Test the model
y_pred = pipeline.predict(X_test_pca)

# Calculate the accuracy
accuracy = accuracy_score(y_test_labels, y_pred)
print(f"Naive Bayes Model Accuracy: {accuracy:.4f}")
# Out:
# Naive Bayes Model Accuracy: 0.2708

# %%
# Create a pipeline with imputation and Perceptron
pipeline = Pipeline([
    ('imputer', SimpleImputer(strategy='mean')),  # Impute missing values
    ('perceptron', Perceptron(max_iter=1000, tol=1e-3, random_state=42))
])

# Train the model
pipeline.fit(X_train_pca, y_train_labels)

# Test the model
y_pred = pipeline.predict(X_test_pca)

# Calculate the accuracy
accuracy = accuracy_score(y_test_labels, y_pred)
print(f"Perceptron Model Accuracy: {accuracy:.4f}")
# Out:
# Perceptron Model Accuracy: 0.2046

# %%
# Create a pipeline with imputation and MLPClassifier
pipeline = Pipeline([
    ('imputer', SimpleImputer(strategy='mean')),  # Impute missing values
    ('mlp', MLPClassifier(hidden_layer_sizes=(100,), max_iter=1000, random_state=42))
])

# Train the model
pipeline.fit(X_train_pca, y_train_labels)

# Test the model
y_pred = pipeline.predict(X_test_pca)

# Calculate the accuracy
accuracy = accuracy_score(y_test_labels, y_pred)
print(f"Multilayer Perceptron Model Accuracy: {accuracy:.4f}")
# Out:
# Multilayer Perceptron Model Accuracy: 0.2778

# %%
# Create individual classifiers
nb = GaussianNB()
dt = DecisionTreeClassifier(random_state=42)
rf = RandomForestClassifier(n_estimators=1000, random_state=42)
perceptron = Perceptron(max_iter=1000, tol=1e-3, random_state=42)

# Create a voting classifier
voting_clf = VotingClassifier(estimators=[
    ('naive_bayes', nb),
    ('decision_tree', dt),
    ('random_forest', rf),
    ('perceptron', perceptron)
], voting='hard')  # Use 'soft' for probabilistic voting

# Create a pipeline with imputation and the ensemble classifier
pipeline = Pipeline([
    ('imputer', SimpleImputer(strategy='mean')),  # Impute missing values
    ('voting_clf', voting_clf)
])

# Train the model
pipeline.fit(X_train_pca, y_train_labels)

# Test the model
y_pred = pipeline.predict(X_test_pca)

# Calculate the accuracy
accuracy = accuracy_score(y_test_labels, y_pred)
print(f"Ensemble Model Accuracy: {accuracy:.4f}")
# Out:
# Ensemble Model Accuracy: 0.3021

# %%
# # model_filename = 'trained_random_forest_model.pkl'
# # with open(model_filename, 'rb') as file:
# #     loaded_model = pickle.load(file)

# # importances = loaded_model.feature_importances_

# importances = rf.feature_importances_

# # Define feature sizes
# edges_size = 100
# orb_size = 0
# hog_size = 3888
# lbp_size = 30
# color_histogram_size = 768  # Assuming 256 bins for each of B, G, R channels

# # Sizes for new features
# harris_size = 100  # Assuming PCA reduced Harris features to 100
# gabor_size = 100   # Assuming PCA reduced Gabor features to 100
# sobel_size = 100   # Assuming PCA reduced Sobel features to 100
# gftt_size = 200    # Assuming PCA reduced GFTT features to 100
# glcm_size = 256 

# # Split importances back into the respective feature categories
# edges_importance = importances[:edges_size]
# orb_importance = importances[edges_size:edges_size + orb_size]
# hog_importance = importances[edges_size + orb_size:edges_size + orb_size + hog_size]
# lbp_importance = importances[edges_size + orb_size + hog_size:edges_size + orb_size + hog_size + lbp_size]
# color_histogram_importance = importances[edges_size + orb_size + hog_size + lbp_size:edges_size + orb_size + hog_size + lbp_size + color_histogram_size]

# # Adding Harris, Gabor, Sobel, and GFTT features
# start_idx = edges_size + orb_size + hog_size + lbp_size + color_histogram_size
# harris_importance = importances[start_idx:start_idx + harris_size]
# gabor_importance = importances[start_idx + harris_size:start_idx + harris_size + gabor_size]
# sobel_importance = importances[start_idx + harris_size + gabor_size:start_idx + harris_size + gabor_size + sobel_size]
# gftt_importance = importances[start_idx + harris_size + gabor_size + sobel_size:start_idx + harris_size + gabor_size + sobel_size + gftt_size]
# glcm_importance = importances[start_idx + harris_size + gabor_size + sobel_size + gftt_size:start_idx + harris_size + gabor_size + sobel_size + gftt_size + glcm_size]

# # Sum the importances for each category
# category_importances = {
#     'edges': (np.sum(edges_importance), edges_size),
#     'orb_features': (np.sum(orb_importance), orb_size),
#     'hog_features': (np.sum(hog_importance), hog_size),
#     'lbp_features': (np.sum(lbp_importance), lbp_size),
#     'color_histogram': (np.sum(color_histogram_importance), color_histogram_size),
#     'harris_features': (np.sum(harris_importance), harris_size),
#     'gabor_features': (np.sum(gabor_importance), gabor_size),
#     'sobel_features': (np.sum(sobel_importance), sobel_size),
#     'gftt_features': (np.sum(gftt_importance), gftt_size),
#     'glcm_features': (np.sum(glcm_importance), glcm_size)
# }

# # Convert to pandas DataFrame for easier viewing
# category_importances_df = pd.DataFrame(category_importances, index=['Importance', 'Feature Count']).T

# # Print the importances by category and feature count
# print(category_importances_df.sort_values(by='Importance', ascending=False))

# %%
# # Compute the confusion matrix
# cm = confusion_matrix(y_test, y_pred)

# # Plot the confusion matrix using seaborn
# plt.figure(figsize=(10, 7))
# sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=set(y), yticklabels=set(y))
# plt.xlabel("Predicted")
# plt.ylabel("Actual")
# plt.title("Confusion Matrix")
# plt.show()
